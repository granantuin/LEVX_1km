# %%
# !pip install -r "/content/drive/MyDrive/Colab Notebooks/LEVX_1km/requirements.txt"

# %%
# !pip install lazypredict

# %%
import plotly.express as px
import pandas as pd
import numpy as np
coor=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/LEVX_1km/input_files/distan_lat42.22lon-8.63p2R1Km.csv")
px.set_mapbox_access_token("pk.eyJ1IjoiZ3JhbmFudHVpbiIsImEiOiJja3B4dGU4OTkwMTFmMm9ycnNhMjJvaGJqIn0.VWzx_PkD9A5cSUVsn_ijCA")
px.scatter_mapbox(coor, hover_data=['distance'],lat='lat', lon='lon',color='distance', title="Nearest points",
                           color_continuous_scale=px.colors.cyclical.IceFire,)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="22f350ae-0303-4a98-a94b-15795a36ca3d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22f350ae-0303-4a98-a94b-15795a36ca3d")) {                    Plotly.newPlot(                        "22f350ae-0303-4a98-a94b-15795a36ca3d",                        [{"customdata": [[0.246], [1.087]], "hovertemplate": "lat=%{lat}<br>lon=%{lon}<br>distance=%{marker.color}<extra></extra>", "lat": [42.21779, 42.22975], "legendgroup": "", "lon": [-8.630013, -8.628961], "marker": {"color": [0.246, 1.087], "coloraxis": "coloraxis"}, "mode": "markers", "name": "", "showlegend": false, "subplot": "mapbox", "type": "scattermapbox"}],                        {"coloraxis": {"colorbar": {"title": {"text": "distance"}}, "colorscale": [[0.0, "#000000"], [0.0625, "#001f4d"], [0.125, "#003786"], [0.1875, "#0e58a8"], [0.25, "#217eb8"], [0.3125, "#30a4ca"], [0.375, "#54c8df"], [0.4375, "#9be4ef"], [0.5, "#e1e9d1"], [0.5625, "#f3d573"], [0.625, "#e7b000"], [0.6875, "#da8200"], [0.75, "#c65400"], [0.8125, "#ac2301"], [0.875, "#820000"], [0.9375, "#4c0000"], [1.0, "#000000"]]}, "legend": {"tracegroupgap": 0}, "mapbox": {"accesstoken": "pk.eyJ1IjoiZ3JhbmFudHVpbiIsImEiOiJja3B4dGU4OTkwMTFmMm9ycnNhMjJvaGJqIn0.VWzx_PkD9A5cSUVsn_ijCA", "center": {"lat": 42.22377, "lon": -8.629487000000001}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "zoom": 8}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.888888888888 ...

# %%
import pandas as pd
station = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/LEVX_1km/input_files/LEVX_20192020.csv",
                          usecols = ["time","mslp_o"],
                          parse_dates=["time"]).set_index("time")
station["mslp_o"].describe()
# Out:
# count    41349.000000
# mean      1018.342378
# std          6.953664
# min        986.000000
# 25%       1015.000000
# 50%       1018.000000
# 75%       1022.000000
# max       1036.000000
# Name: mslp_o, dtype: float64

# %% [markdown]
# **Forecast D0**

# %%
#forecast d0
model1k = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/LEVX_1km/input_files/lat42.22lon-8.63p2R1KmD0.csv",parse_dates=["time"]).drop(columns=["Unnamed: 0"]).set_index("time")
model1k
# Out:
#                            dir0  snow_prec0   snowlevel0      mod0  \
# time
# 2019-01-01 01:00:00  143.268921         0.0  1801.360962  0.789023
# 2019-01-01 02:00:00  152.222214         0.0  1766.035156  1.437459
# 2019-01-01 03:00:00  154.053619         0.0  1728.199341  1.304144
# 2019-01-01 04:00:00  162.321548         0.0  1716.658325  1.242218
# 2019-01-01 05:00:00  167.243256         0.0  1718.675293  0.790160
# ...                         ...         ...          ...       ...
# 2020-12-31 19:00:00  316.116913         0.0   800.844543  5.403949
# 2020-12-31 20:00:00  318.488983         0.0   708.539551  4.331174
# 2020-12-31 21:00:00  314.300262         0.0   763.025513  3.515929
# 2020-12-31 22:00:00  265.415161         0.0   740.638245  1.696378
# 2020-12-24 21:00:00  24082.583984  ...    0.0 -0.000215   0.0   0.0   0.0
# 2020-12-24 22:00:00  24096.234375  ...    0.0 -0.000211   0.0   0.0   0.0
# 2020-12-24 23:00:00  24178.738281  ...    0.0  0.000289   0.0   0.0   0.0
#
#                      cft1      HGT5001      HGT8501       T5001       T8501
# time
# 2019-01-01 01:00:00   0.0  5730.042969  1595.621948  253.857193  283.275238
# 2019-01-01 02:00:00   0.0  5729.319824  1597.058472  253.848557  282.842499
# 2019-01-01 03:00:00   0.0  5724.619141  1593.626953  253.876816  282.377808
# 2019-01-01 04:00:00   0.0  5725.305664  1596.243408  253.810440  282.195923
# 2019-01-01 05:00:00   0.0  5724.179199  1596.257935  253.821121  282.136566
# ...                   ...          ...          ...         ...         ...
# 2020-12-24 19:00:00   0.0  5529.350586  1529.656250  248.538376  273.540680
# 2020-12-24 20:00:00   0.0  5534.803223  1534.443115  248.254623  273.497437
# 2020-12-24 21:00:00   0.0  5545.419434  1536.551025  248.680069  273.530487
# 2020-12-24 22:00:00   0.0  5543.265625  1539.952026  248.775055  273.804199
# 2020-12-24 23:00:00   0.0  5550.753418  1533.942505  249.275620  274.178070
#
# [16468 rows x 51 columns]

# %%
np.rint(df_all1k["mslp0"]/100)
# Out:
# time
# 2019-01-01 01:00:00    1032.0
# 2019-01-01 02:00:00    1032.0
# 2019-01-01 03:00:00    1031.0
# 2019-01-01 04:00:00    1032.0
# 2019-01-01 05:00:00    1032.0
#                         ...
# 2020-12-24 19:00:00    1028.0
# 2020-12-24 20:00:00    1029.0
# 2020-12-24 21:00:00    1030.0
# 2020-12-24 22:00:00    1029.0
# 2020-12-24 23:00:00    1029.0
# Name: mslp0, Length: 16468, dtype: float64

# %% [markdown]
# **Point 0**

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

#MAE en m/s
MAE = mean_absolute_error(df_all1k["mslp_o"],df_all1k["mslp0"]/100)
#MSE en m/s
MSE = mean_squared_error(df_all1k["mslp_o"], df_all1k["mslp0"]/100)
#R2
R2 = r2_score(df_all1k["mslp_o"], df_all1k["mslp0"]/100)


df_r = pd.DataFrame({"MAE":MAE,"MSE":MSE,"R2":R2},index=["result"]);
df_r
# Out:
#              MAE       MSE        R2
# result  0.704944  0.871937  0.980961

# %% [markdown]
# **Point 1**

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

#MAE en m/s
MAE = mean_absolute_error(df_all1k["mslp_o"],df_all1k["mslp1"]/100)
#MSE en m/s
MSE = mean_squared_error(df_all1k["mslp_o"], df_all1k["mslp1"]/100)
#R2
R2 = r2_score(df_all1k["mslp_o"], df_all1k["mslp1"]/100)


df_r = pd.DataFrame({"MAE":MAE,"MSE":MSE,"R2":R2},index=["result"]);
df_r
# Out:
#              MAE       MSE        R2
# result  0.695654  0.845488  0.981539

# %%
df_all1k.columns
x_var = ['snowlevel0','temp0', 'rh0', 'visibility0','prec0', 'shflx0','cft0',
         'T5000', 'T8500', 'dir1','snowlevel1','temp1','rh1', 'visibility1',
         'prec1','swflx1', 'shflx1','cft1','T5001', 'T8501']

# %%
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor

# X and Y
Y = df_all1k["mslp_o"]
X = df_all1k.iloc[:,1:]
#X = df_all1k[x_var]

X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, )


multiple_model = LazyRegressor(verbose =0, ignore_warnings = True,predictions=True)
models,predictions = multiple_model.fit(X_train,X_test,y_train,y_test)
# Out:
#  95%|█████████▌| 39/41 [05:28<00:10,  5.14s/it]
# [09:54:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 100%|██████████| 41/41 [05:32<00:00,  8.12s/it]

# %%
models
# Out:
#                                                               Adjusted R-Squared  \
# Model
# ExtraTreesRegressor                                                         0.99
# LGBMRegressor                                                               0.99
# HistGradientBoostingRegressor                                               0.99
# RandomForestRegressor                                                       0.99
# BaggingRegressor                                                            0.99
# LassoLarsCV                                                                 0.99
# TransformedTargetRegressor                                                  0.99
# LinearRegression                                                            0.99
# RidgeCV                                                                     0.99
# Ridge                                                                       0.99
# BayesianRidge                                                               0.99
# HuberRegressor                                                              0.99
# PoissonRegressor                                                            0.99
# RANSACRegressor                                                             0.99
# LinearSVR                                                                   0.99
# GradientBoostingRegressor                                                   0.99
# LassoCV                                                                     0.99
# ElasticNetCV                                                                0.99
# XGBRegressor                                                                0.99
# OrthogonalMatchingPursuitCV                                                 0.99
# OrthogonalMatchingPursuit                                                   0.99
# LarsCV                                                                      0.99
# LassoLarsIC                                                                 0.99
# PassiveAggressiveRegressor                                                  0.98
# DecisionTreeRegressor                                                       0.98
# AdaBoostRegressor                                                           0.98
# ExtraTreeRegressor                                                          0.98
# SVR                                                                         0.97
# NuSVR                                                                       0.97
# Lasso                                                                       0.96
# KNeighborsRegressor                                                         0.95
# TweedieRegressor                                                            0.94
# GammaRegressor                                                              0.94
# ElasticNet                                                                  0.93
# DummyRegressor                                                             -0.02
# LassoLars                                                                  -0.02
# MLPRegressor                                                               -9.68
# SGDRegressor                                                              -25.79
# GaussianProcessRegressor                                                -6038.42
# KernelRidge                                                            -23196.76
# Lars                          -2372613780337354749323196774156542164490655614...
#
#                                                                        R-Squared  \
# Model
# ExtraTreesRegressor                                                         0.99
# LGBMRegressor                                                               0.99
# HistGradientBoostingRegressor                                               0.99
# RandomForestRegressor                                                       0.99
# BaggingRegressor                                                            0.99
# LassoLarsCV                                                                 0.99
# TransformedTargetRegressor                                                  0.99
# LinearRegression                                                            0.99
# RidgeCV                                                                     0.99
# Ridge                                                                       0.99
# BayesianRidge                                                               0.99
# HuberRegressor                                                              0.99
# PoissonRegressor                                                            0.99
# RANSACRegressor                                                             0.99
# LinearSVR                                                                   0.99
# GradientBoostingRegressor                                                   0.99
# LassoCV                                                                     0.99
# ElasticNetCV                                                                0.99
# XGBRegressor                                                                0.99
# OrthogonalMatchingPursuitCV                                                 0.99
# OrthogonalMatchingPursuit                                                   0.99
# LarsCV                                                                      0.99
# LassoLarsIC                                                                 0.99
# PassiveAggressiveRegressor                                                  0.98
# DecisionTreeRegressor                                                       0.98
# AdaBoostRegressor                                                           0.98
# ExtraTreeRegressor                                                          0.98
# SVR                                                                         0.97
# NuSVR                                                                       0.97
# Lasso                                                                       0.96
# KNeighborsRegressor                                                         0.95
# TweedieRegressor                                                            0.94
# GammaRegressor                                                              0.94
# ElasticNet                                                                  0.93
# DummyRegressor                                                             -0.00
# LassoLars                                                                  -0.00
# MLPRegressor                                                               -9.51
# SGDRegressor                                                              -25.38
# GaussianProcessRegressor                                                -5946.71
# KernelRidge                                                            -22844.53
# Lars                          -2336588669794728943423657505874142876539616419...
#
#                                                                     RMSE  \
# Model
# ExtraTreesRegressor                                                 0.66
# LGBMRegressor                                                       0.70
# HistGradientBoostingRegressor                                       0.70
# RandomForestRegressor                                               0.71
# BaggingRegressor                                                    0.74
# LassoLarsCV                                                         0.75
# TransformedTargetRegressor                                          0.75
# LinearRegression                                                    0.75
# RidgeCV                                                             0.75
# Ridge                                                               0.75
# BayesianRidge                                                       0.75
# HuberRegressor                                                      0.75
# PoissonRegressor                                                    0.75
# RANSACRegressor                                                     0.75
# LinearSVR                                                           0.75
# GradientBoostingRegressor                                           0.75
# LassoCV                                                             0.76
# ElasticNetCV                                                        0.77
# XGBRegressor                                                        0.79
# OrthogonalMatchingPursuitCV                                         0.81
# OrthogonalMatchingPursuit                                           0.81
# LarsCV                                                              0.81
# LassoLarsIC                                                         0.81
# PassiveAggressiveRegressor                                          0.91
# DecisionTreeRegressor                                               0.99
# AdaBoostRegressor                                                   1.00
# ExtraTreeRegressor                                                  1.01
# SVR                                                                 1.12
# NuSVR                                                               1.12
# Lasso                                                               1.29
# KNeighborsRegressor                                                 1.54
# TweedieRegressor                                                    1.68
# GammaRegressor                                                      1.69
# ElasticNet                                                          1.72
# DummyRegressor                                                      6.74
# LassoLars                                                           6.74
# MLPRegressor                                                       21.85
# SGDRegressor                                                       34.61
# GaussianProcessRegressor                                          519.63
# KernelRidge                                                      1018.40
# Lars                          102992819820357040961808724519662125056.00
#
#                                Time Taken
# Model
# ExtraTreesRegressor                 10.62
# LGBMRegressor                        1.33
# HistGradientBoostingRegressor       10.99
# RandomForestRegressor               43.83
# BaggingRegressor                     4.11
# LassoLarsCV                          0.42
# TransformedTargetRegressor           0.08
# LinearRegression                     0.09
# RidgeCV                              0.12
# Ridge                                0.06
# BayesianRidge                        0.17
# HuberRegressor                       2.53
# PoissonRegressor                     0.38
# RANSACRegressor                      0.31
# LinearSVR                            3.02
# GradientBoostingRegressor           18.93
# LassoCV                              1.03
# ElasticNetCV                         0.98
# XGBRegressor                         3.55
# OrthogonalMatchingPursuitCV          0.19
# OrthogonalMatchingPursuit            0.05
# LarsCV                               0.44
# LassoLarsIC                          0.10
# PassiveAggressiveRegressor           0.13
# DecisionTreeRegressor                0.77
# AdaBoostRegressor                    6.16
# ExtraTreeRegressor                   0.18
# SVR                                 16.91
# NuSVR                               15.59
# Lasso                                0.38
# KNeighborsRegressor                  1.33
# TweedieRegressor                     0.08
# GammaRegressor                       0.08
# ElasticNet                           0.06
# DummyRegressor                       0.04
# LassoLars                            0.06
# MLPRegressor                        31.57
# SGDRegressor                         0.13
# GaussianProcessRegressor           112.38
# KernelRidge                         43.52
# Lars                                 0.19

# %% [markdown]
# **LGBMRegressor**

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

MAE = round(mean_absolute_error(y_test, predictions.LGBMRegressor),1)
MSE = round(mean_squared_error(y_test, predictions.LGBMRegressor),1)
R2 = round(r2_score(y_test, predictions.LGBMRegressor),2)
df_r=pd.DataFrame({"MAE":MAE,"MSE":MSE,"R2":R2},index=["resultados"]);
print(df_r)
# Out:
#             MAE  MSE   R2
# resultados 0.50 0.50 0.99

# %% [markdown]
# **ExtraTreesRegressor**

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

MAE = round(mean_absolute_error(y_test, predictions.ExtraTreesRegressor),1)
MSE = round(mean_squared_error(y_test, predictions.ExtraTreesRegressor),1)
R2 = round(r2_score(y_test, predictions.ExtraTreesRegressor),2)
df_r=pd.DataFrame({"MAE":MAE,"MSE":MSE,"R2":R2},index=["resultados"]);
print(df_r)
# Out:
#             MAE  MSE   R2
# resultados 0.50 0.40 0.99

# %% [markdown]
# **lgbmregressor**

# %%
from sklearn.metrics import accuracy_score
from lightgbm.sklearn import LGBMRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score



# X and Y
Y = df_all1k.mslp_o
X = df_all1k.iloc[:,1:]

# loop random
acc=[]
for t in range (0,10):
  #split variables
  X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.15, )

  
  ml_model = LGBMRegressor().fit(X_train,y_train)
  y_pred = ml_model.predict(X_test)
  MAE = round(mean_absolute_error(y_test, y_pred),1)
  MSE = round(mean_squared_error(y_test, y_pred),1)
  R2 = round(r2_score(y_test, y_pred),2)
  df_r=pd.DataFrame({"MAE":MAE,"MSE":MSE,"R2":R2},index=["resultados"]);
  print(df_r)
# Out:
#             MAE  MSE   R2
# resultados 0.60 0.50 0.99
#             MAE  MSE   R2
# resultados 0.50 0.50 0.99
#             MAE  MSE   R2
# resultados 0.50 0.50 0.99
#             MAE  MSE   R2
# resultados 0.50 0.50 0.99
#             MAE  MSE   R2
# resultados 0.50 0.50 0.99
#             MAE  MSE   R2
# resultados 0.50 0.50 0.99
#             MAE  MSE   R2
# resultados 0.60 0.50 0.99
#             MAE  MSE   R2
# resultados 0.50 0.50 0.99
#             MAE  MSE   R2
# resultados 0.50 0.50 0.99
#             MAE  MSE   R2
# resultados 0.60 0.50 0.99

# %%
df_all1k["hour"] = df_all1k.index.hour
df_all1k["month"] = df_all1k.index.month
df_all1k["dayofyear"] = df_all1k.index.dayofyear
df_all1k["weekofyear"] = df_all1k.index.isocalendar().week.astype(int)

# %%
from sklearn.metrics import accuracy_score
from lightgbm.sklearn import LGBMRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score



# X and Y
Y = df_all1k.mslp_o
X = df_all1k.iloc[:,1:]

# loop random
acc=[]
for t in range (0,10):
  #split variables
  X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.15, )

  
  ml_model = LGBMRegressor().fit(X_train,y_train)
  y_pred = ml_model.predict(X_test)
  MAE = round(mean_absolute_error(y_test, y_pred),1)
  MSE = round(mean_squared_error(y_test, y_pred),1)
  R2 = round(r2_score(y_test, y_pred),2)
  df_r=pd.DataFrame({"MAE":MAE,"MSE":MSE,"R2":R2},index=["resultados"]);
  print(df_r)
# Out:
#             MAE  MSE   R2
# resultados 0.50 0.40 0.99
#             MAE  MSE   R2
# resultados 0.50 0.40 0.99
#             MAE  MSE   R2
# resultados 0.50 0.50 0.99
#             MAE  MSE   R2
# resultados 0.50 0.40 0.99
#             MAE  MSE   R2
# resultados 0.50 0.40 0.99
#             MAE  MSE   R2
# resultados 0.50 0.40 0.99
#             MAE  MSE   R2
# resultados 0.50 0.40 0.99
#             MAE  MSE   R2
# resultados 0.50 0.40 0.99
#             MAE  MSE   R2
# resultados 0.50 0.50 0.99
#             MAE  MSE   R2
# resultados 0.50 0.40 0.99

# %%
import pickle
from sklearn.pipeline import Pipeline

x_var = df_all1k.iloc[:,1:].columns
estimators = [('ml_model', ml_model)]
pipe = Pipeline(estimators)
print(pipe)
al_file={"x_var":x_var,"coor":coor,"pipe":pipe}
pickle.dump(al_file, open("pres_LEVX_1km_time_d0.al", 'wb'))
# Out:
# Pipeline(steps=[('ml_model', LGBMRegressor())])
