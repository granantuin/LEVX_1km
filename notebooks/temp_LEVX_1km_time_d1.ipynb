# %%
# !pip install -r "/content/drive/MyDrive/Colab Notebooks/LEVX_1km/requirements.txt"

# %%
# !pip install lazypredict

# %%
import plotly.express as px
import pandas as pd
import numpy as np
coor=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/LEVX_1km/input_files/distan_lat42.22lon-8.63p2R1Km.csv")
px.set_mapbox_access_token("pk.eyJ1IjoiZ3JhbmFudHVpbiIsImEiOiJja3B4dGU4OTkwMTFmMm9ycnNhMjJvaGJqIn0.VWzx_PkD9A5cSUVsn_ijCA")
px.scatter_mapbox(coor, hover_data=['distance'],lat='lat', lon='lon',color='distance', title="Nearest points",
                           color_continuous_scale=px.colors.cyclical.IceFire,)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
station = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/LEVX_1km/input_files/LEVX_20192020.csv",
                          usecols = ["time","temp_o"],
                          parse_dates=["time"]).set_index("time")
station["temp_o"].describe()
# Out:
# count    41305.000000
# mean       287.467008
# std          5.499157
# min        273.150000
# 25%        283.150000
# 50%        287.150000
# 75%        291.150001
# max        310.149999
# Name: temp_o, dtype: float64

# %% [markdown]
# **Forecast D1**

# %%
#forecast d0
model1k = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/LEVX_1km/input_files/lat42.22lon-8.63p2R1KmD1.csv",parse_dates=["time"]).drop(columns=["Unnamed: 0"]).set_index("time")
model1k
# Out:
#                            dir0  snow_prec0   snowlevel0      mod0  \
# time
# 2019-01-02 00:00:00  325.189301         0.0  1740.084961  1.217145
# 2019-01-02 01:00:00  333.670044         0.0  1731.173340  1.369249
# 2019-01-02 02:00:00  351.552429         0.0  1721.331055  1.275996
# 2019-01-02 03:00:00   33.307388         0.0  1717.657593  0.696653
# 2019-01-02 04:00:00  164.234100         0.0  1696.665771  0.224833
# ...                         ...         ...          ...       ...
# 2021-01-01 19:00:00  297.835388         0.0   766.453003  6.263795
# 2021-01-01 20:00:00  305.522644         0.0   769.984497  5.884632
# 2021-01-01 21:00:00  304.144806         0.0   787.868713  6.053614
# 2021-01-01 22:00:00  293.481812         0.0   775.807739  5.027291
# 2021-01-01 23:00:00  281.385010         0.0   760.383911  4.213167
#
#                      wind_gust0          mslp0       temp0       rh0  \
# time
# 2019-01-02 00:00:00    2.264327  103401.195312  280.789246  0.781950
# ...

# %%
#concat station model
df_all1k = pd.concat([station,model1k],axis=1).dropna()
df_all1k
# Out:
#                          temp_o        dir0  snow_prec0   snowlevel0  \
# time
# 2019-01-02 00:00:00  280.149999  325.189301         0.0  1740.084961
# 2019-01-02 02:00:00  278.150000  351.552429         0.0  1721.331055
# 2019-01-02 03:00:00  278.150000   33.307388         0.0  1717.657593
# 2019-01-02 04:00:00  278.150000  164.234100         0.0  1696.665771
# 2019-01-02 05:00:00  277.150000  172.277390         0.0  1675.816650
# ...                         ...         ...         ...          ...
# 2020-12-24 19:00:00  280.149999   15.196351         0.0  1130.906982
# 2020-12-24 20:00:00  279.150000   16.350925         0.0  1122.497314
# 2020-12-24 21:00:00  278.150000   14.447461         0.0  1130.548462
# 2020-12-24 22:00:00  278.150000   15.328802         0.0  1128.692017
# 2020-12-24 23:00:00  278.150000   15.208591         0.0  1093.965942
#
#                          mod0  wind_gust0          mslp0       temp0  \
# time
# ...

# %% [markdown]
# **Meteorological model score (MAE)**

# %% [markdown]
# **Point 0**

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

#MAE en m/s
MAE=round(mean_absolute_error(df_all1k["temp_o"], df_all1k["temp0"]),2)
#MSE en m/s
MSE=round(mean_squared_error(df_all1k["temp_o"], df_all1k["temp0"]),2)
#R2
R2=round(r2_score(df_all1k["temp_o"], df_all1k["temp0"]),2)


df_r=pd.DataFrame({"MAE":MAE,"MSE":MSE,"R2":R2},index=["results"]);
df_r
# Out:
#           MAE   MSE    R2
# results  1.43  3.44  0.89

# %%
#MAE in 20 samples
concat = df_all1k[["temp_o","temp0"]]
MAE_met = []

for t in range (0,20):
  #sample lenght as y_test machine learning
  concat_t = concat.sample(3294)
  MAE_met.append(round(mean_absolute_error(concat_t["temp_o"], concat_t["temp0"]),2))
  
print(pd.DataFrame(MAE_met,columns=["MAE"]).describe()) 
print("\nMAE list:") 
MAE0 = np.around(MAE_met, decimals=2)
MAE0
# Out:
#              MAE
# count  20.000000
# mean    1.434500
# std     0.015381
# min     1.410000
# 25%     1.427500
# 50%     1.430000
# 75%     1.440000
# max     1.470000
#
# MAE list:
# array([1.46, 1.47, 1.42, 1.44, 1.42, 1.43, 1.44, 1.44, 1.43, 1.45, 1.45,
#        1.43, 1.44, 1.43, 1.42, 1.43, 1.41, 1.44, 1.43, 1.41])

# %% [markdown]
# **Compare MAE point 0 day 0 vs MAE pòint 0 day 1**

# %%
import scipy.stats as stats


#MAE point 0 (day 0 mean=1.45 day 1 mean=1.434) better d1 than d0 !!
MAE0_d0 = np.array([1.46, 1.45, 1.43, 1.47, 1.49, 1.46, 1.43, 1.43, 1.43, 1.48, 1.46,
       1.5 , 1.47, 1.45, 1.46, 1.45, 1.45, 1.44, 1.45, 1.46])


#Null Hypothesis H0 mean1=mean2

_,p_value=stats.ttest_ind(MAE0,MAE0_d0,equal_var= False)

print("p_value:",p_value)
if p_value < 0.05:    # alpha value is 0.05 or 5%
    print("we are rejecting null hypothesis  H0 mean1=mean2")
else:
    print("we are accepting null hypothesis  H0 mean1=mean2")
# Out:
# p_value: 0.00044982327379741147
# we are rejecting null hypothesis  H0 mean1=mean2

# %% [markdown]
# **Meteorological model point 1**

# %%
#MAE en m/s
MAE=round(mean_absolute_error(df_all1k["temp_o"], df_all1k["temp1"]),2)
#MSE en m/s
MSE=round(mean_squared_error(df_all1k["temp_o"], df_all1k["temp1"]),2)
#R2
R2=round(r2_score(df_all1k["temp_o"], df_all1k["temp0"]),2)


df_r=pd.DataFrame({"MAE":MAE,"MSE":MSE,"R2":R2},index=["results"]);
df_r
# Out:
#           MAE   MSE    R2
# results  1.51  3.75  0.89

# %%
#MAE in 20 samples
concat = df_all1k[["temp_o","temp1"]]
MAE_met = []

for t in range (0,20):
  #sample lenght as y_test machine learning
  concat_t = concat.sample(3294)
  MAE_met.append(round(mean_absolute_error(concat_t["temp_o"], concat_t["temp1"]),2))
  
print(pd.DataFrame(MAE_met,columns=["MAE"]).describe()) 
print("\nMAE list:") 
MAE1 = np.around(MAE_met, decimals=2)
MAE1
# Out:
#             MAE
# count  20.00000
# mean    1.50800
# std     0.02353
# min     1.46000
# 25%     1.49000
# 50%     1.51000
# 75%     1.53000
# max     1.54000
#
# MAE list:
# array([1.52, 1.5 , 1.53, 1.54, 1.53, 1.5 , 1.52, 1.49, 1.53, 1.51, 1.46,
#        1.54, 1.52, 1.49, 1.49, 1.53, 1.49, 1.46, 1.51, 1.5 ])

# %% [markdown]
# **Compare point 0 vs 1 (Mean Abssolute Error t test)**

# %%
import scipy.stats as stats


#Null Hypothesis H0 mean1=mean2

_,p_value=stats.ttest_ind(MAE0,MAE1,equal_var= True)

print("p_value:",p_value)
if p_value < 0.05:    # alpha value is 0.05 or 5%
    print("we are rejecting null hypothesis  H0 mean1=mean2")
else:
    print("we are accepting null hypothesis  H0 mean1=mean2")
# Out:
# p_value: 3.7225640392911856e-14
# we are rejecting null hypothesis  H0 mean1=mean2

# %% [markdown]
# **Find ML algorithm**

# %%
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor

# X and Y
Y = round(df_all1k["temp_o"])-273
X = df_all1k.iloc[:,1:]
#X = df_all1k[x_var]

X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, )


multiple_model = LazyRegressor(verbose =0, ignore_warnings = True,predictions=True)
models,predictions = multiple_model.fit(X_train,X_test,y_train,y_test)
# Out:
#  95%|█████████▌| 39/41 [03:27<00:08,  4.05s/it]
# [09:43:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 100%|██████████| 41/41 [03:30<00:00,  5.14s/it]

# %%
models
# Out:
#                                Adjusted R-Squared        R-Squared       RMSE  \
# Model
# ExtraTreesRegressor                          0.96             0.96       1.17
# LGBMRegressor                                0.95             0.95       1.22
# RandomForestRegressor                        0.95             0.95       1.23
# HistGradientBoostingRegressor                0.95             0.95       1.23
# BaggingRegressor                             0.94             0.94       1.31
# SVR                                          0.94             0.94       1.39
# GradientBoostingRegressor                    0.94             0.94       1.39
# XGBRegressor                                 0.94             0.94       1.39
# NuSVR                                        0.94             0.94       1.40
# LinearSVR                                    0.93             0.93       1.48
# LassoCV                                      0.92             0.93       1.52
# ...

# %% [markdown]
# **LGBMRegressor**

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

MAE = round(mean_absolute_error(y_test, predictions.LGBMRegressor),1)
MSE = round(mean_squared_error(y_test, predictions.LGBMRegressor),1)
R2 = round(r2_score(y_test, predictions.LGBMRegressor),2)
df_r=pd.DataFrame({"MAE":MAE,"MSE":MSE,"R2":R2},index=["resultados"]);
print(df_r)
# Out:
#             MAE  MSE   R2
# resultados 1.00 1.50 0.95

# %% [markdown]
# **ExtraTreesRegressor**

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

MAE = round(mean_absolute_error(y_test, predictions.ExtraTreesRegressor),1)
MSE = round(mean_squared_error(y_test, predictions.ExtraTreesRegressor),1)
R2 = round(r2_score(y_test, predictions.ExtraTreesRegressor),2)
df_r=pd.DataFrame({"MAE":MAE,"MSE":MSE,"R2":R2},index=["resultados"]);
print(df_r)
# Out:
#             MAE  MSE   R2
# resultados 0.90 1.40 0.96

# %% [markdown]
# **lgbmregressor ML algorithm selected**

# %%
from sklearn.metrics import accuracy_score
from lightgbm.sklearn import LGBMRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score



# X and Y
Y = df_all1k.temp_o
X = df_all1k.iloc[:,1:]

# loop random
MAE_ml =[]
for t in range (0,20):
  #split variables
  X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.15, )

  
  ml_model = LGBMRegressor().fit(X_train,y_train)
  y_pred = ml_model.predict(X_test)
  MAE = round(mean_absolute_error(y_test, y_pred),2)
  MAE_ml.append(MAE)
  MSE = round(mean_squared_error(y_test, y_pred),2)
  R2 = round(r2_score(y_test, y_pred),2)
  df_r=pd.DataFrame({"MAE":MAE,"MSE":MSE,"R2":R2},index=["results"]);
  print(df_r)

print(pd.DataFrame(MAE_ml,columns=["MAE_ml"]).describe())
MAE_ml
# Out:
#          MAE  MSE   R2
# results 0.99 1.69 0.95
#          MAE  MSE   R2
# results 0.96 1.54 0.95
#          MAE  MSE   R2
# results 0.97 1.62 0.95
#          MAE  MSE   R2
# results 0.96 1.55 0.95
#          MAE  MSE   R2
# results 0.95 1.55 0.95
#          MAE  MSE   R2
# results 1.02 1.76 0.94
#          MAE  MSE   R2
# results 0.97 1.62 0.95
#          MAE  MSE   R2
# results 0.96 1.58 0.95
#          MAE  MSE   R2
# results 0.98 1.65 0.95
#          MAE  MSE   R2
# results 0.98 1.66 0.95
#          MAE  MSE   R2
# results 0.95 1.53 0.95
#          MAE  MSE   R2
# results 0.99 1.70 0.94
#          MAE  MSE   R2
# results 0.99 1.68 0.95
#          MAE  MSE   R2
# results 0.94 1.52 0.95
#          MAE  MSE   R2
# results 0.96 1.56 0.95
#          MAE  MSE   R2
# results 0.98 1.66 0.95
#          MAE  MSE   R2
# results 0.95 1.54 0.95
#          MAE  MSE   R2
# results 0.96 1.57 0.95
#          MAE  MSE   R2
# results 0.95 1.51 0.95
#          MAE  MSE   R2
# results 0.97 1.60 0.95
# ...

# %% [markdown]
# **Compare machine learning vs meteorological model point o (t test)**

# %%
import scipy.stats as stats

#Null Hypothesis H0 mean1=mean2

_,p_value=stats.ttest_ind(MAE0,MAE_ml,equal_var= False)

print("p_value:",p_value)
if p_value < 0.05:    # alpha value is 0.05 or 5%
    print("we are rejecting null hypothesis  H0 mean1=mean2")
else:
    print("we are accepting null hypothesis  H0 mean1=mean2")
# Out:
# p_value: 2.574221077182799e-43
# we are rejecting null hypothesis  H0 mean1=mean2

# %% [markdown]
# **Add time variables**

# %%
df_all1k["hour"] = df_all1k.index.hour
df_all1k["month"] = df_all1k.index.month
df_all1k["dayofyear"] = df_all1k.index.dayofyear
df_all1k["weekofyear"] = df_all1k.index.isocalendar().week.astype(int)

# %%
#train new model
from sklearn.metrics import accuracy_score
from lightgbm.sklearn import LGBMRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score



# X and Y
Y = df_all1k.temp_o
X = df_all1k.iloc[:,1:]

# loop random
MAE_t = []
for t in range (0,20):
  #split variables
  X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.15, )

  
  ml_model = LGBMRegressor().fit(X_train,y_train)
  y_pred = ml_model.predict(X_test)
  MAE = round(mean_absolute_error(y_test, y_pred),2)
  MAE_t.append(MAE)
  MSE = round(mean_squared_error(y_test, y_pred),2)
  R2 = round(r2_score(y_test, y_pred),2)
  df_r=pd.DataFrame({"MAE":MAE,"MSE":MSE,"R2":R2},index=["results"]);
  print(df_r)


print(pd.DataFrame(MAE_t,columns=["MAE_ml"]).describe())
MAE_t
# Out:
#          MAE  MSE   R2
# results 0.88 1.33 0.96
#          MAE  MSE   R2
# results 0.90 1.38 0.96
#          MAE  MSE   R2
# results 0.88 1.31 0.96
#          MAE  MSE   R2
# results 0.89 1.36 0.96
#          MAE  MSE   R2
# results 0.91 1.43 0.96
#          MAE  MSE   R2
# results 0.91 1.41 0.96
#          MAE  MSE   R2
# results 0.90 1.42 0.95
#          MAE  MSE   R2
# results 0.89 1.36 0.96
#          MAE  MSE   R2
# results 0.91 1.41 0.95
#          MAE  MSE   R2
# results 0.88 1.34 0.96
#          MAE  MSE   R2
# results 0.90 1.36 0.96
#          MAE  MSE   R2
# results 0.89 1.35 0.96
#          MAE  MSE   R2
# results 0.92 1.43 0.95
#          MAE  MSE   R2
# results 0.89 1.37 0.96
#          MAE  MSE   R2
# results 0.87 1.29 0.96
#          MAE  MSE   R2
# results 0.87 1.30 0.96
#          MAE  MSE   R2
# results 0.91 1.43 0.95
#          MAE  MSE   R2
# results 0.88 1.35 0.96
#          MAE  MSE   R2
# results 0.92 1.45 0.95
#          MAE  MSE   R2
# results 0.87 1.30 0.96
# ...

# %% [markdown]
# **Test ML algorithm with and without time features**

# %%
#Null Hypothesis H0 mean1=mean2

_,p_value=stats.ttest_ind(MAE_t,MAE_ml,equal_var= True)

print("p_value:",p_value)
if p_value < 0.05:    # alpha value is 0.05 or 5%
    print("we are rejecting null hypothesis  H0 mean1=mean2")
else:
    print("we are accepting null hypothesis  H0 mean1=mean2")
# Out:
# p_value: 5.424781423476955e-16
# we are rejecting null hypothesis  H0 mean1=mean2

# %% [markdown]
# **Save algorithm**

# %%
import pickle
from sklearn.pipeline import Pipeline

x_var = df_all1k.iloc[:,1:].columns
estimators = [('ml_model', ml_model)]
pipe = Pipeline(estimators)
print(pipe)
al_file={"x_var":x_var,"coor":coor,"pipe":pipe}
pickle.dump(al_file, open("temp_LEVX_1km_time_d1.al", 'wb'))
# Out:
# Pipeline(steps=[('ml_model', LGBMRegressor())])
